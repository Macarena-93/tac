# %% [markdown]
# # Extraction de Keywords

# %% [markdown]
# ## Imports

# %%
import os
import yake

# %% [markdown]
# ## Extraire les mots clés d'un document avec Yake

# %% [markdown]
# https://github.com/LIAAD/yake

# %%
# Instantier l'extracteur de mots clés

kw_extractor = yake.KeywordExtractor(lan="fr", top=50)
kw_extractor

# %%
# Lister les Fichiers
data_path = "../../data/txt/"
files = [f for f in os.listdir(data_path) if f.endswith('.txt')]

# %%
# Imprimer le nombre de fichiers identifiés
len(files)
# Out:
# 7986

# %%
# Les dix premiers fichiers
files[:10]
# Out:
# ['KB_JB230_1892-08-07_01-0003.txt',
#  'KB_JB230_1903-10-16_01-0002.txt',
#  'KB_JB230_1913-07-05_01-0001.txt',
#  'KB_JB258_1884-09-03_01-0003.txt',
#  'KB_JB258_1894-12-09_01-0003.txt',
#  'KB_JB258_1906-01-09_01-0002.txt',
#  'KB_JB421_1899-05-15_01-00003.txt',
#  'KB_JB421_1926-10-29_01-00002.txt',
#  'KB_JB421_1950-04-15_01-00004.txt',
#  'KB_JB427_1920-01-10_01-00004.txt']

# %%
# Choisir un fichier
this_file = files[0]
this_file
# Out:
# 'KB_JB230_1892-08-07_01-0003.txt'

# %%
# Récupérer le texte du fichier
text = open(os.path.join(data_path, this_file), 'r', encoding='utf-8').read()
text[:500]
# Out:
# "llUr fili ont tiibi «veeS£\nU section  nor- \niceés l’examen  de sortie oour  \nfoWentiet  dn diplCmo  d’institairke.\nCe qui Km (frappé  quand  H noua a été donné  de \nràier [ Institut,  c m le caractère  de distinction  qal \nai rnpraac  aux élèves  par naedireettoart  ne g rores  \nfe «alureaes  de premier  ordre.  la loa. ta tenue  août  \nurftita. « ce a'eat  pas une choea banale  que de troo-  \nïer one Kaison  où l’on s'occupe,  en Même  tempe  qoe \nrtruer  Mer esprit  et de développer  leur into"

# %%
# Extraire les mots clés de ce texte
keywords = kw_extractor.extract_keywords(text)
keywords
# Out:
# [('août', 0.002587294645268218),
#  ('rue', 0.0049824184500938725),
#  ('froment', 0.009941977243734754),
#  ('Bruxelles', 0.01105227363696716),
#  ('notaire Verhaegen', 0.013465558945681553),
#  ('notaire', 0.013972879428444995),
#  ('centiares', 0.015997066175768952),
#  ('notaire Verhaegen adjugera', 0.018252158204188434),
#  ('prix', 0.021060184032059014),
#  ('ans', 0.02311900103416283),
#  ('kilo', 0.024737640012042834),
#  ('avoine', 0.03221491589779668),
#  ('seigle', 0.03379109234253124),
#  ('kilos', 0.03401425501655889),
#  ('contenance', 0.0344100125328466),
#  ('marché', 0.03535010627349762),
#  ('contenant', 0.036338668695391804),
#  ('d’une contenance', 0.0376892615913991),
#  ('chaussée', 0.040180081042302244),
#  ('pommes', 0.04053200569010122),
#  ('septembre', 0.041093730149432794),
#  ('Verhaegen', 0.04245966015280319),
#  ('colza', 0.04326550904395864),
#  ('orge', 0.046238870036947516),
#  ('ares', 0.048558445941720006),
#  ('lin', 0.04884694140833543),
# ...

# %%
# Ne garder que les bigrammes
kept = []
for kw, score in keywords:
    words = kw.split()
    if len(words) == 2:
        kept.append(kw)
kept
# Out:
# ['notaire Verhaegen',
#  'd’une contenance',
#  'Verhaegen adjugera',
#  'llUr fili',
#  'située rue',
#  "bénéfice d'enchères",
#  'rue Van']

# %% [markdown]
# ## Faire la même opération sur tous les documents

# %%
for f in sorted(files)[:10]:
    text = open(os.path.join(data_path, f), 'r', encoding="utf-8").read()
    keywords = kw_extractor.extract_keywords(text)
    kept = []
    for kw, score in keywords:
        words = kw.split()
        if len(words) == 2:
            kept.append(kw)
    print(f"{f} mentions these keywords: {', '.join(kept)}...")
# Out:
# KB_JB230_1892-08-07_01-0003.txt mentions these keywords: notaire Verhaegen, d’une contenance, Verhaegen adjugera, llUr fili, située rue, bénéfice d'enchères, rue Van...
# KB_JB230_1903-10-16_01-0002.txt mentions these keywords: Mme Loubet, roi d’Italie, plus grande, Liste catholique...
# KB_JB230_1913-07-05_01-0001.txt mentions these keywords: compte rendu, Dans tous, budget belge, libéral socialiste, Grande Duchesse, oompto rendu, parti libérai, projet scolaire...
# KB_JB258_1884-09-03_01-0003.txt mentions these keywords: loi loi, loi eet...
# KB_JB258_1894-12-09_01-0003.txt mentions these keywords: ’hui dimanche, Camille Dreyfus, qooo Ueuroi, Dreyfus aurait...
# KB_JB258_1906-01-09_01-0002.txt mentions these keywords: faiiit Joese, Ciit.it dan, Pauline dans, Lire demain, Maître d’Ecole, provoquer dans, isVvé dans, mieruetneni dans, ne-t dan, Mme Krauss, Oct lot...
# ...

# %% [markdown]
# ## TP2 : Extraction des mots-clés de l'année 1951

# %% [markdown]
# Filtre par rapport à une année choisie

# %%
files_1951 = [f for f in files if "1951" in f]

# %% [markdown]
# Vérification que le filtre avait fonctionné en vérifiant la quantité de documents

# %%
len(files_1951)
# Out:
# 100

# %% [markdown]
# Extraction des mots-clés des documents relatifs à cette année

# %%
for f in sorted(files_1951):
    text = open(os.path.join(data_path, f), 'r', encoding="utf-8").read()
    keywords = kw_extractor.extract_keywords(text)
    kept = []
    for kw, score in keywords:
        words = kw.split()
        if len(words) == 2:
            kept.append(kw)
    print(f"{f} mentions these keywords: {', '.join(kept)}...")
# Out:
# KB_JB838_1951-01-04_01-00009.txt mentions these keywords: rue Royale, Francis Croisset, Marthe Dugard., Bourse Tél, VENTE PUBLIQUE, UCCLE Rue, Enf. adm...
# KB_JB838_1951-01-06_01-00004.txt mentions these keywords: prie d’annoncer, GENERAL Fonte, tient lieu, AVIS TIENT, MAUVAIS TEMPS, demeurant rue, jeune homme, Vendredi matin...
# KB_JB838_1951-01-07_01-00002.txt mentions these keywords: îles Kerguélen, Georges Bidault, Pierre Loe, D’autres allergènes, l'enseignement religieux, devenir ouvertement...
# KB_JB838_1951-01-11_01-00004.txt mentions these keywords: nous prie, demeurant rue, prie d’annoncer, SABENA poursuit, incendie s’est, habitant rue, tient lieu, d’une maison, MADAME VEUVE...
# KB_JB838_1951-01-13_01-00012.txt mentions these keywords: Agence Rossel, Bel app, Ecrire Agence, louer maison, LOUER rue, Rossel numéro, app. mod...
# ...
