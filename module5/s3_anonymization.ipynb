# %% [markdown]
# # Anonymisation de données

# %% [markdown]
# ## Imports

# %%
from pprint import pprint
from faker import Faker
from faker.providers import internet

# %% [markdown]
# "Faker is a Python package that generates fake data for you. Whether you need to bootstrap your database, create good-looking XML documents, fill-in your persistence to stress test it, or anonymize data taken from a production service, Faker is for you."
#
# https://faker.readthedocs.io/en/master/

# %% [markdown]
# "Use `faker.Faker()` to create and initialize a faker generator, which can generate data by accessing properties named after the type of data you want."

# %%
fake = Faker()

# %% [markdown]
# ## Créer un faux nom

# %%
print(fake.name())
# Out:
# Anne Brown

# %%
# Il est possible de créer plusieurs faux noms, ici en français, avec une boucle.
fake_fr = Faker('fr_FR')
for _ in range(10):
    print(fake_fr.name())
# Out:
# Alix Colin-Dupré
# Théodore Tanguy
# Margot Hardy
# Océane Carlier
# Monique Morin
# Gabrielle Renaud
# Patrick-Édouard Petitjean
# Antoine Teixeira Le Laporte
# Adrien Leroy
# Margaud Arnaud

# %%
# Même chose en néerlandais.
fake_nl = Faker('nl_NL')
for _ in range(10):
    print(fake_nl.name())
# Out:
# Senn van der Klijn
# Simon Driessen
# Amelia Schenkel
# Quinten van de Wiel-Jansdr
# Yusuf van Luin
# David Molenaar
# Melissa de Leeuw
# Nisa Boer-die Witte
# Nina Huberts
# Ali Hermans-van de Pavert

# %% [markdown]
# ## Créer une fausse adresse

# %%
# Pour créer une fausse adresse.
print(fake.address())
# Out:
# Unit 4310 Box 7344
# DPO AP 50481

# %% [markdown]
# ## Créer une fausse adresse IP

# %%
fake.add_provider(internet)
print(fake.ipv4_public())
# Out:
# 178.62.28.45

# %% [markdown]
# ## Créer un faux profil complet

# %%
profile = fake_fr.simple_profile()
pprint(profile)
# Out:
# {'address': 'rue de Lévy\n33414 Bouchetboeuf',
#  'birthdate': datetime.date(1936, 1, 16),
#  'mail': 'honoredelaunay@live.com',
#  'name': 'Georges-Lucas Girard',
#  'sex': 'M',
#  'username': 'lebrunjulien'}
